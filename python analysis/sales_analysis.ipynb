# %%
import pandas as pd
import numpy as np

# %%
# Add encoding parameter to handle non-UTF-8 characters
# Common encodings to try: 'latin1', 'ISO-8859-1', 'cp1252'
df = pd.read_csv(r"C:\Users\Mancoba\Desktop\Retail-Sales-Analytics-Project\data\raw data\Sample - Superstore.csv", 
                 encoding='latin1')

# If the above doesn't work, you can try other encodings:
# encoding='ISO-8859-1'
# encoding='cp1252'

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order Date']
# Out:
# 0        11/8/2016
# 1        11/8/2016
# 2        6/12/2016
# 3       10/11/2015
# 4       10/11/2015
#            ...
# 9989     1/21/2014
# 9990     2/26/2017
# 9991     2/26/2017
# 9992     2/26/2017
# 9993      5/4/2017
# Name: Order Date, Length: 9994, dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ### QUICK BUSINESS INSIGHT PREVIEW

# %% [markdown]
# ### Total Sales

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603)

# %% [markdown]
# ### Total Profit

# %%
df['Profit'].sum()
# Out:
# np.float64(286397.0217)

# %% [markdown]
# ### Average Discount

# %%
df['Discount'].mean()
# Out:
# np.float64(0.1562027216329798)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['ship_date'] = pd.to_datetime(df['ship_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9994 non-null   int64
#  1   order_id       9994 non-null   object
#  2   order_date     9994 non-null   datetime64[ns]
#  3   ship_date      9994 non-null   datetime64[ns]
#  4   ship_mode      9994 non-null   object
#  5   customer_id    9994 non-null   object
#  6   customer_name  9994 non-null   object
#  7   segment        9994 non-null   object
#  8   country        9994 non-null   object
#  9   city           9994 non-null   object
#  10  state          9994 non-null   object
#  11  postal_code    9994 non-null   int64
#  12  region         9994 non-null   object
#  13  product_id     9994 non-null   object
#  14  category       9994 non-null   object
#  15  sub-category   9994 non-null   object
#  16  product_name   9994 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# row_id           0
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub-category     0
# product_name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# dtype: int64

# %% [markdown]
# ### 1️⃣ Order Year

# %%
df['order_year'] = df['order_date'].dt.year

# %% [markdown]
# ### 2️⃣ Order Month

# %%
df['order_month'] = df['order_date'].dt.month

# %% [markdown]
# ### 3️⃣ Month Name (better for dashboards)

# %%
df['month_name'] = df['order_date'].dt.month_name()

# %% [markdown]
# ### 4️⃣ Profit Margin
#
# ### Profit margin helps evaluate profitability.

# %%
df['profit_margin'] = df['profit'] / df['sales']

# %% [markdown]
# ### Quick Analytical Checks
#
# ### Let us begin extracting simple insights.
#
# ## Total Sales

# %%
df['sales'].sum()
# Out:
# np.float64(2297200.8603)

# %% [markdown]
# ## Total Profit

# %%
df['profit'].sum()
# Out:
# np.float64(286397.0217)

# %% [markdown]
# ### Top Regions by Sales

# %%
df.groupby('region')['sales'].sum().sort_values(ascending=False)
# Out:
# region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: sales, dtype: float64

# %% [markdown]
# ### Top Product Categories

# %%
df.groupby('category')['sales'].sum().sort_values(ascending=False)
# Out:
# category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: sales, dtype: float64

# %% [markdown]
# ### — Export Clean Dataset

# %%
df.to_csv(r"C:\Users\Mancoba\Desktop\Retail-Sales-Analytics-Project\data\cleaned_data\superstore_cleaned.csv", index=False)

# %%
df['sales'].sum()
# Out:
# np.float64(2297200.8603)

# %%
df
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      customer_id     customer_name    segment        country             city  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Mancoba\Desktop\Retail-Sales-Analytics-Project\data\cleaned_data\superstore_cleaned.csv")

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['ship_date'] = pd.to_datetime(df['ship_date'])

# %%
df.shape
# Out:
# (9994, 25)

# %%
df.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   sub-category                                       product_name     sales  \
# ...

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit', 'order_year',
#        'order_month', 'month_name', 'profit_margin'],
#       dtype='object')

# %%
df.groupby('region')['sales'].sum()
# Out:
# region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: sales, dtype: float64

# %%
df.groupby('region')['profit'].sum().sort_values(ascending=False)
# Out:
# region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: profit, dtype: float64

# %%
df.groupby('category')['sales'].sum().sort_values(ascending=False)
# Out:
# category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: sales, dtype: float64

# %%
df.groupby('category')['profit'].sum().sort_values(ascending=False)
# Out:
# category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: profit, dtype: float64

# %%
df.groupby('category')['discount'].mean()
# Out:
# category
# Furniture          0.173923
# Office Supplies    0.157285
# Technology         0.132323
# Name: discount, dtype: float64

# %%
df.groupby('month_name')['sales'].sum().sort_values(ascending=False)
# Out:
# month_name
# November     352461.0710
# December     325293.5035
# September    307649.9457
# March        205005.4888
# October      200322.9847
# August       159044.0630
# May          155028.8117
# June         152718.6793
# July         147238.0970
# April        137762.1286
# January       94924.8356
# February      59751.2514
# Name: sales, dtype: float64

# %%
df.groupby(['order_year','order_month'])['sales'].sum()
# Out:
# order_year  order_month
# 2014        1               14236.8950
#             2                4519.8920
#             3               55691.0090
#             4               28295.3450
#             5               23648.2870
#             6               34595.1276
#             7               33946.3930
#             8               27909.4685
#             9               81777.3508
#             10              31453.3930
#             11              78628.7167
#             12              69545.6205
# 2015        1               18174.0756
#             2               11951.4110
#             3               38726.2520
#             4               34195.2085
#             5               30131.6865
#             6               24797.2920
#             7               28765.3250
#             8               36898.3322
#             9               64595.9180
#             10              31404.9235
#             11              75972.5635
# ...

# %%
df.groupby('segment')['sales'].sum().sort_values(ascending=False)
# Out:
# segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: sales, dtype: float64

# %%
df['order_id'].nunique()
# Out:
# 5009

# %%
import pandas as pd
import numpy as np

# %%
df.to_excel(r"C:\Users\Mancoba\Desktop\Retail-Sales-Analytics-Project\data\cleaned_data\superstore_cleaned.xlsx", index=False)
